# %% [markdown]
# Merhaba ben Nuray

# %% [markdown]
# # Yeni Bölüm

# %% [markdown]
# İGÜSEM OTONOM SİSTEMLERİ EĞİTİMİ
# Bu kod blogu üzerinde ggogle driev ile google colab platformlarının eşleşmesi sağlanmakatdır. Eşleşme anında drive alanınızda aşağıdaki kod içerisinde olan "IGUSEM_OTONOM"dosyası olmak zorundadır.
# Nuray Fırat
# Ocak 2026

# %%
print ("Merhaba Hayat, IGU SEM egitimi Otonom Sistemler 20.01.2026")
# Out:
# Merhaba Hayat, IGU SEM egitimi Otonom Sistemler 20.01.2026

# %%
import sys #import python programlama dilinde kütüphane eklemeye yarayan bir kod blogudur.
print(sys.version)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/IGUSEM_OTONOM')
# !pwd # ilk kod blogunun cıktısını bize veren bir kod blogudur.
# Out:
# /content/drive/My Drive/IGUSEM_OTONOM
